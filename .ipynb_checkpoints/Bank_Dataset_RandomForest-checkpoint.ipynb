# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/manishanker/statistics_ML_jan_2020/master/bank.csv',sep=';')

# %%
df
# Out:
#       age            job  marital  education default balance housing loan  \
# 0      30     unemployed  married    primary      no    1787      no   no
# 1      33       services  married  secondary      no    4789     yes  yes
# 2      35     management   single   tertiary      no    1350     yes   no
# 3      30     management  married   tertiary      no    1476     yes  yes
# 4      59    blue-collar  married  secondary      no       0     yes   no
# ...   ...            ...      ...        ...     ...     ...     ...  ...
# 4516   33       services  married  secondary      no    -333     yes   no
# 4517   57  self-employed  married   tertiary     yes   -3313     yes  yes
# 4518   57     technician  married  secondary      no     295      no   no
# 4519   28    blue-collar  married  secondary      no    1137      no   no
# 4520   44            NaN      NaN   tertiary      no    1136     yes  yes
#
#        contact   day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4518 non-null   object
#  2   marital    4518 non-null   object
#  3   education  4518 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4520 non-null   object
#  6   housing    4520 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4518 non-null   object
#  9   day        4520 non-null   float64
#  10  month      4521 non-null   object
#  11  duration   4519 non-null   float64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4518 non-null   object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 600.6+ KB

# %%
df.isna().sum()/df.shape[0]
# Out:
# age          0.000000
# job          0.000664
# marital      0.000664
# education    0.000664
# default      0.000000
# balance      0.000221
# housing      0.000221
# loan         0.000000
# contact      0.000664
# day          0.000221
# month        0.000000
# duration     0.000442
# campaign     0.000000
# pdays        0.000000
# previous     0.000000
# poutcome     0.000000
# y            0.000664
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4504, 17)

# %%
### Retriving the column names whose datatype is 'object'.
object_dtype_columns = list(df.select_dtypes(include=['O']).columns)
print((object_dtype_columns))
# Out:
# ['job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# %%
### Checking the number of unique values present in each object type columns.  

a=[]
for i in object_dtype_columns:
    print(i)
    print("Unique Values= ",len(df[i].unique()))
    a.append(len(df[i].unique()))
    print()
print(sum(a))
# Out:
# job
# Unique Values=  12
#
# marital
# Unique Values=  3
#
# education
# Unique Values=  5
#
# default
# Unique Values=  2
#
# balance
# Unique Values=  2346
#
# housing
# Unique Values=  2
#
# loan
# Unique Values=  2
#
# contact
# Unique Values=  3
#
# month
# Unique Values=  12
#
# poutcome
# Unique Values=  4
#
# y
# Unique Values=  6
#
# 2397

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance       object
# housing       object
# loan          object
# contact       object
# day          float64
# month         object
# duration     float64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
### Here we can see that the datatype of balance is object. Hence checking the values.

# %%
df.astype({'balance':"float64"}).dtypes

# %%
print(list(df.balance))
# Out:
# ['1787', '4789', '1350', '1476', '0', '747', '307', '147', '221', '-88', '9374', '264', '1109', '502', '194', '4073', '2317', '-221', '132', '0', '16', '106', '93', '543', '5883', '627', '696', '784', '105', '4189', '171', '42', '2536', '1235', '1811', '229', '2089', '3935', '363', '11971', '553', '1117', '396', '2204', '872', '0', '-849', '4629', '844', '228', '50', '1539', '2231', '3064', '82', '101', '784', '-516', '415', '5887', '1355', '16873', '203', '338', '444', '0', '360', '0', '2', '412', '344', '3222', '174', '591', '388', '219', '451', '5', '177', '657', '1315', '1466', '879', '293', '424', '1831', '111', '455', '-195', '14093', '1567', '5426', '261', '2843', '406', '0', '493', '5996', '3777', '524', '574', '427', '483', '3391', '0', '2488', '1517', '331', '505', '1808', '4111', '52', '25', '1890', '419', '2693', '-231', '-55', '462', '119', '586', '228', '4659', '168', '0', '-715', '0', '769', '0', '428', '0', '-970', '6313', '948', '0', '1877', '874', '323', '106', '190
# ...

# %%
df=df[df.balance!='MANI']

# %%
### It was found that there were 2 rows with the name "MANI" which wasn't required. Hence those 2 rows were dropped.

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance       object
# housing       object
# loan          object
# contact       object
# day          float64
# month         object
# duration     float64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
df=df.astype({'balance':"float64"})

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day          float64
# month         object
# duration     float64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no   1787.0      no   no
# 1      33       services  married  secondary      no   4789.0     yes  yes
# 2      35     management   single   tertiary      no   1350.0     yes   no
# 3      30     management  married   tertiary      no   1476.0     yes  yes
# 4      59    blue-collar  married  secondary      no      0.0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4515   32       services   single  secondary      no    473.0     yes   no
# 4516   33       services  married  secondary      no   -333.0     yes   no
# 4517   57  self-employed  married   tertiary     yes  -3313.0     yes  yes
# 4518   57     technician  married  secondary      no    295.0      no   no
# 4519   28    blue-collar  married  secondary      no   1137.0      no   no
#
# ...

# %%
### Retriving the column names whose datatype is 'object'.
object_dtype_columns = list(df.select_dtypes(['O']))
print((object_dtype_columns))
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']

# %%
for i in object_dtype_columns:
    print(i)
    print(list(df[i].unique()))
    print()
# Out:
# job
# ['unemployed', 'services', 'management', 'blue-collar', 'self-employed', 'technician', 'entrepreneur', 'admin.', 'student', 'housemaid', 'retired', 'unknown']
#
# marital
# ['married', 'single', 'divorced']
#
# education
# ['primary', 'secondary', 'tertiary', 'unknown', 'na']
#
# default
# ['no', 'yes']
#
# housing
# ['no', 'yes']
#
# loan
# ['no', 'yes']
#
# contact
# ['cellular', 'unknown', 'telephone']
#
# month
# ['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jul', 'nov', 'jan', 'sep', 'mar', 'dec']
#
# poutcome
# ['unknown', 'failure', 'other', 'success']
#
# y
# ['no', 'yes', 'No', 'NO', 'Yes', 'yEs']

# %%
## We can clearly see that the outcome variable 'y' is not properly encoded.

# %%
# Encoding the column 'y'.

df.y=df.y.map({'no':0,'yes':1,'No':0,'NO':0,'Yes':1,'yEs':1})

# %%
df.y.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
### Retriving the column names whose datatype is 'object'.

object_dtype_columns = list(df.select_dtypes(['O']))
print((object_dtype_columns))
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']

# %%
### Checking the number of unique values present in each object type columns.  

a=[]
for i in object_dtype_columns:
    print(i)
    print("Unique Values= ",len(df[i].unique()))
    a.append(len(df[i].unique()))
    print()
print("Total sum of unique values= ",sum(a))
# Out:
# job
# Unique Values=  12
#
# marital
# Unique Values=  3
#
# education
# Unique Values=  5
#
# default
# Unique Values=  2
#
# housing
# Unique Values=  2
#
# loan
# Unique Values=  2
#
# contact
# Unique Values=  3
#
# month
# Unique Values=  12
#
# poutcome
# Unique Values=  4
#
# Total sum of unique values=  45

# %% [markdown]
# #### Here if one hot encoding is used then 45 new columns would be created.
#
# #### Hence lets use mean encoding to change the categorical variables into numerical variables.

# %%
df1=df.copy()

# %%
### Defining Mean Encoding.
def Mean_encoding(df,datacolumn,target):
    mean_ordinal=df.groupby(datacolumn)[target].mean().to_dict()
    df['mean_encode '+datacolumn]=df[datacolumn].map(mean_ordinal)
    df=df.drop(datacolumn,axis=1)    
    return df

# %%
### Using Mean Encoding technique to replace the values in object_dtype_columns into float values.

for i in object_dtype_columns:
    df1=Mean_encoding(df1,i,'y')

# %%
df1.y.value_counts()
# Out:
# 0    3981
# 1     521
# Name: y, dtype: int64

# %%
## Checking whether the dataset is an imbalanced dataset or not.
df1.y.value_counts()/df1.shape[0]*100
# Out:
# 0    88.427366
# 1    11.572634
# Name: y, dtype: float64

# %% [markdown]
# #### Here we can clearly see that the dataset is highly imbalanced.
# #### Hence lets adopt the over sampling technique to convert this imbalanced dataset into a balanced one.

# %% [markdown]
# ### Lets first split the dataset into subcribed to term deposit and not subcribed to term deposit.

# %%
subscribed=df1[df1.y==1]
not_subscribed=df1[df1.y==0]

# %%
subscribed.shape,not_subscribed.shape
# Out:
# ((521, 17), (3981, 17))

# %%
X=df1.drop(['y'],axis=1)
y=df1['y']

# %%
### Using imblearn library to convert the imbalanced dataset into balanced one. 

from imblearn.combine import SMOTETomek
smk=SMOTETomek(random_state=42)
X_res,y_res=smk.fit_sample(X,y)

# %%
X_res.shape,y_res.shape
# Out:
# ((7670, 16), (7670,))

# %%
from collections import Counter
print('Original dataset shape {}'.format(Counter(y)))
print('Reshaped dataset shape {}'.format(Counter(y_res)))
# Out:
# Original dataset shape Counter({0: 3981, 1: 521})
# Reshaped dataset shape Counter({0: 3835, 1: 3835})

# %% [markdown]
# #### Here we can clearly see that the dataset that was fed has been balanced.

# %%
df2=pd.concat([X_res,y_res],axis=1)

# %%
df2.isna().sum()
# Out:
# age                      0
# balance                  0
# day                      0
# duration                 0
# campaign                 0
# pdays                    0
# previous                 0
# mean_encode job          0
# mean_encode marital      0
# mean_encode education    0
# mean_encode default      0
# mean_encode housing      0
# mean_encode loan         0
# mean_encode contact      0
# mean_encode month        0
# mean_encode poutcome     0
# y                        0
# dtype: int64

# %% [markdown]
# ## Using logistic regression algorithm

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
e=[]
for i in range(1,100):
    X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.20,random_state=i)
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    b=accuracy_score(y_test, y_pred)
    e.append(b)
    print("Random state is =",i)
    print("Accuracy score is =",b)
    print()
print("The highest accuracy score is =", max(e))
print("The average accuracy score is =", sum(e)/len(e))
# Out:
# Random state is = 1
# Accuracy score is = 0.8305084745762712
#
# Random state is = 2
# Accuracy score is = 0.8402868318122555
#
# Random state is = 3
# Accuracy score is = 0.8363754889178618
#
# Random state is = 4
# Accuracy score is = 0.833116036505867
#
# Random state is = 5
# Accuracy score is = 0.8396349413298566
#
# Random state is = 6
# Accuracy score is = 0.8109517601043025
#
# Random state is = 7
# Accuracy score is = 0.8402868318122555
#
# Random state is = 8
# Accuracy score is = 0.8441981747066493
#
# Random state is = 9
# Accuracy score is = 0.8324641460234681
#
# Random state is = 10
# Accuracy score is = 0.8461538461538461
#
# Random state is = 11
# Accuracy score is = 0.833767926988266
#
# Random state is = 12
# Accuracy score is = 0.8292046936114733
#
# Random state is = 13
# Accuracy score is = 0.8246414602346805
#
# Random state is = 14
# Accuracy score is = 0.8468057366362451
#
# Random state is = 15
# Accuracy score is = 0.8259452411994785
#
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       779
#            1       0.85      0.79      0.82       755
#
#     accuracy                           0.83      1534
#    macro avg       0.83      0.83      0.83      1534
# weighted avg       0.83      0.83      0.83      1534

# %%
from collections import Counter
Counter(y_pred)
# Out:
# Counter({1: 703, 0: 831})

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[675, 104],
#        [156, 599]], dtype=int64)

# %% [markdown]
# ### Now let us use random forest algorithm to train our model

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier

# a=[]
c=[]
b=0
for l in range (1,11):
    for k in range(15,20):
        for j in range(1,10):
#             for i in range(1,10):
                X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.20,random_state=j)
                clf = RandomForestClassifier(max_depth=l,n_estimators=k,random_state=None)
                clf.fit(X_train,y_train)
                y_pred=clf.predict(X_test)
                b=metrics.accuracy_score(y_test,y_pred)
#                 a.append(b)
                c.append(b)
                print("Max depth of the classifier= ",l)
                print("The n_estimator is= ",k)
                print("Random state of train_test split= ",j)
#                 print("Random state of the classifier is= ",i)
                print("The best accuracy value of this train and test split is=",b)
                print()
#                 b=0
#                 a=[]
print("The maximum accuracy value is=",max(c))
print("The average accuracy value is=", (sum(c)/len(c)))
# Out:
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  1
# The best accuracy value of this train and test split is= 0.7933507170795306
#
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  2
# The best accuracy value of this train and test split is= 0.8089960886571056
#
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  3
# The best accuracy value of this train and test split is= 0.7907431551499348
#
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  4
# The best accuracy value of this train and test split is= 0.8161668839634941
#
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  5
# The best accuracy value of this train and test split is= 0.8376792698826597
#
# Max depth of the classifier=  1
# The n_estimator is=  15
# Random state of train_test split=  6
# ...

# %% [markdown]
# ### Using the above best parameters to train our model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.20,random_state=8)
clf = RandomForestClassifier(max_depth=10,n_estimators=17,random_state=10)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9426336375488917

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[744,  63],
#        [ 25, 702]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       807
#            1       0.92      0.97      0.94       727
#
#     accuracy                           0.94      1534
#    macro avg       0.94      0.94      0.94      1534
# weighted avg       0.94      0.94      0.94      1534

# %% [markdown]
# ### Here we can clearly see that the precision, recall and f1-score i.e., the accuracy of the model is pretty good when compared to logistic regression. Hence we can adopt this method to train our model.
